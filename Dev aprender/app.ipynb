# %%
age = 28
name = "Rafael"
print(f"Meu nome é {name} e eu tenho {age} ano(s) de idade.")
# Out:
# Meu nome é Rafael e eu tenho 28 ano(s) de idade.

# %%
nome = "Guilherme"
idade = 28

print(nome, idade)
# Out:
# Guilherme 28

# %%
nome = input("Informe seu nome: ")
idade = input("Informe a sua idade: ")

print(nome, idade)
# Out:
# Rafael 41

# %% [markdown]
# Saldo é diferente de saque?

# %%
saldo = 200
saque = 200

print(saldo != saque)
# Out:
# False

# %% [markdown]
# Atribuição por adição

# %%
saldo  = 500
saldo += 200

print(saldo)
# Out:
# 700

# %%
def sacar(valor):
    saldo = 500

    if saldo >= valor:
        print("valor sacado!")
        print("retire o seu dinheiro na boca do caixa.")

    print("Obrigado por ser nosso cliente, tenha um bom dia")

sacar(10000)
# Out:
# Obrigado por ser nosso cliente, tenha um bom dia
